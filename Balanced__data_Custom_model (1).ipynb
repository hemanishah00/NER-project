# %% [markdown]
# ### Overview

# %% [markdown]
# The Basic Idea behind this model is to train different models for different porposes. As Neural Networks are black box models; It is hard to define a method that it can follow.
# As the data is highly imbalanced and the number of categories is large.</br>
# We wanted to create a less biased model which still has a considerably large training sample.</br>
# As the WIESP dataset follow the "B-" and "I-" convention from the IOB2 syntax.</br>
# We wanted to see if the model can predict better once we predict which tags are in the B-, I- and O category.</br>
# We will be creating categories and then sub categories.</br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We have created the model as shown above. We have preprocessed the input and output as need for the purpose it serves. Initailly, we were hoping that this model would give us atleast a less biased model.</br>
# We have used the same elmo model architecture, as it was performing well, as compared to other architectures.</br>
# Reference for the elmo model architecture: https://medium.com/analytics-vidhya/named-entity-recognition-using-deep-learning-elmo-embedding-bi-lstm-48295bc66cab

# %% [markdown]
# ### Preprocessing

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import statistics as st
import tensorflow as tf
from math import ceil
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import confusion_matrix,classification_report

# %matplotlib inline

# %%
# Importing data from drive
data = pd.read_json('/content/drive/MyDrive/AI-3/Project/fgrezes:WIESP2022-NER/WIESP2022-NER-TRAINING.jsonl', lines=True)
tags = pd.read_json('/content/drive/MyDrive/AI-3/fgrezes:WIESP2022-NER/ner_tags.json', lines=True)
tags = tags.T.reset_index()

# %%
# Having a look at the distribution of B-I-O
print("""
B tags:""")
print(tags['index'].loc[:30])
print("""
I tags:""")
print(tags['index'].loc[31:61])
print("""
O tags:""")
print(tags['index'].loc[62])
# Out:
# B tags:
# 0                     B-Archive
# 1             B-CelestialObject
# 2       B-CelestialObjectRegion
# 3             B-CelestialRegion
# 4                    B-Citation
# 5               B-Collaboration
# 6           B-ComputingFacility
# 7                    B-Database
# 8                     B-Dataset
# 9      B-EntityOfFutureInterest
# 10                      B-Event
# 11                 B-Fellowship
# 12                    B-Formula
# 13                      B-Grant
# 14                 B-Identifier
# 15                 B-Instrument
# 16                   B-Location
# 17                    B-Mission
# 18                      B-Model
# 19    B-ObservationalTechniques
# 20                B-Observatory
# 21               B-Organization
# 22                     B-Person
# 23                   B-Proposal
# 24                   B-Software
# 25                     B-Survey
# 26                        B-Tag
# 27                  B-Telescope
# 28                B-TextGarbage
# 29                        B-URL
# 30                 B-Wavelength
# Name: index, dtype: object
#
# I tags:
# 31                    I-Archive
# 32            I-CelestialObject
# 33      I-CelestialObjectRegion
# 34            I-CelestialRegion
# 35                   I-Citation
# 36              I-Collaboration
# 37          I-ComputingFacility
# 38                   I-Database
# 39                    I-Dataset
# 40     I-EntityOfFutureInterest
# 41                      I-Event
# 42                 I-Fellowship
# 43                    I-Formula
# 44                      I-Grant
# 45                 I-Identifier
# 46                 I-Instrument
# 47                   I-Location
# 48                    I-Mission
# 49                      I-Model
# 50    I-ObservationalTechniques
# 51                I-Observatory
# 52               I-Organization
# 53                     I-Person
# 54                   I-Proposal
# 55                   I-Software
# 56                     I-Survey
# 57                        I-Tag
# 58                  I-Telescope
# 59                I-TextGarbage
# 60                        I-URL
# 61                 I-Wavelength
# Name: index, dtype: object
#
# O tags:
# O

# %%
# Performing train test split
train_data, test_data = train_test_split(data, train_size=0.8, random_state=1)

# %%
# creating a reference_dataset and predictions_dataset for later use
reference_data = test_data[['unique_id','ner_tags']]
predictions_dataset = test_data[['unique_id']]

# %%
# creating a column called unit number
train_data['Unit #'] = train_data.index

#We set the index as the unit number. Then we filter each unit, joininig the text
train_data.set_index('Unit #', inplace=True)

# %%
# creating a column called unit number for test data
test_data['Unit #'] = test_data.index
reference_data['Unit #'] = reference_data.index

# We set the index as the unit number. Then we filter each unit, joininig the text
test_data.set_index('Unit #', inplace=True)
reference_data.set_index('Unit #', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Exploding ner_ids and tokens
train_data = train_data.explode(['ner_ids','tokens','ner_tags'])
test_data = test_data.explode(['ner_ids','tokens','ner_tags'])

# %%
# Since the ner_ids also have the value 0, this can be confusing when we use padding 0.
train_data.ner_ids = train_data.ner_ids.values + 1
test_data.ner_ids = test_data.ner_ids.values + 1

# %%
# One hot encoding if a token belongs to b, i or o
b_i_o = []
for i in train_data['ner_ids']:
  if i == 63:
    b_i_o.append([0,0,1])
  if i >= 1 and i < 32:
    b_i_o.append([1,0,0])
  if i >= 32 and i < 63:
    b_i_o.append([0,1,0])

train_data[['b','i','o']] = b_i_o

# %%
b_i_o = []
for i in test_data['ner_ids']:
  if i == 63:
    b_i_o.append([0,0,1])
  if i >= 1 and i < 32:
    b_i_o.append([1,0,0])
  if i >= 32 and i < 63:
    b_i_o.append([0,1,0])

test_data[['b','i','o']] = b_i_o

# %% [markdown]
# We have not taken out special characters as we understand for tags like urls and formulas, it is necessary for the text to have special characters.

# %%
# Tokenize the words
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=None,
                                                filters='',
                                                lower=True,
                                                split=' ') # Initialize

tokenizer.fit_on_texts(train_data.tokens.values) # Fit on training data

# %%
# Transform to numeric
tokens_train = tokenizer.texts_to_sequences(train_data.tokens.values)
tokens_test = tokenizer.texts_to_sequences(test_data.tokens.values)

# %%
# Have a look at the data to ensure that there are no empty elements
print("The number of empty lists in train data : ",np.array([token==[] for token in tokens_train]).sum())
print("The number of empty lists in test data : ",np.array([token==[] for token in tokens_test]).sum())
# Out:
# The number of empty lists in train data :  0
# The number of empty lists in test data :  7582

# %%
# Remove empty elements
b = np.array([token!=[] for token in tokens_test])
test_data = test_data.iloc[b,:]
tokens_test = np.array(tokens_test)[b]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   after removing the cwd from sys.path.

# %%
# creating a column called tokens.
train_data.tokens = tokens_train
test_data.tokens = tokens_test

train_data.tokens=train_data.tokens.map(lambda x: x[0])
test_data.tokens=test_data.tokens.map(lambda x: x[0])

# %%
# We have kept the size of one unit to be simply 50.
# as this text is not broken down by sentences, it has long length this may lead to vanishing gradients later.
si = 50
IDs_train = train_data.index.unique()
train_sentences = []
train_tags = []
train_Ns = []
train_os = []
train_bs = []
train_is = []

 # For each id
for i in IDs_train:
    # We extract the respective data
    sel = train_data.loc[i]
    # A sentence is a list of tokens
    sentence = sel.tokens.values
    # The tags correspond to each token
    tag = sel['ner_ids'].values 
    o = sel['o']
    b = sel['b']
    i = sel['i']
    
    sen_size = sentence.shape[0]

    if sen_size>si:
      while(sen_size>si):
        # We store the sentences in a list
        train_sentences.append(np.array(sentence[:si]))
        # We do the same with the tags  
        train_tags.append(np.array(tag[:si]))            
        train_os.append(np.array(o[:si]))
        train_bs.append(np.array(b[:si]))
        train_is.append(np.array(i[:si]))
        # And store the length of the sentence
        train_Ns.append(si)
        sentence = sentence[si:]
        tag = tag[si:]
        o = o[si:]
        b = b[si:]
        i = i[si:]
        sen_size = sentence.shape[0]
      train_sentences.append(np.array(sentence))
      train_tags.append(np.array(tag))
      train_os.append(np.array(o))
      train_bs.append(np.array(b))
      train_is.append(np.array(i))
      train_Ns.append(sentence.shape[0])

    # adding the last sentence and tags
    else:
      train_sentences.append(np.array(sentence))
      train_tags.append(np.array(tag))            
      train_os.append(np.array(o[:si]))
      train_bs.append(np.array(b[:si]))
      train_is.append(np.array(i[:si]))
      train_Ns.append(sentence.shape[0])

# %%
# We transform everything into np arrays    
train_Ns = np.array(train_Ns)
train_sentences = np.array(train_sentences)
train_tags = np.array(train_tags)
train_os = np.array(train_os)
train_bs = np.array(train_bs)
train_is = np.array(train_is)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   import sys

# %%
# having a quick look at the shapes of the arrays created above
print(IDs_train.shape, train_Ns.shape, train_sentences.shape, train_tags.shape, train_os.shape, train_bs.shape, train_is.shape)
# Out:
# (1402,) (9779,) (9779,) (9779,) (9779,) (9779,) (9779,)

# %%
# For simplicity, we create a padded array beforehand
train_sentences_padded = tf.keras.preprocessing.sequence.pad_sequences(train_sentences, padding='post')
train_tags_padded = tf.keras.preprocessing.sequence.pad_sequences(train_tags, padding='post')
# here we have 1 describing tags which are not o and 2 describing tags which are o. 0 represents padding
train_os_padded = tf.keras.preprocessing.sequence.pad_sequences(train_os + 1, padding='post')
train_bs_padded = tf.keras.preprocessing.sequence.pad_sequences(train_bs, padding='post')
train_is_padded = tf.keras.preprocessing.sequence.pad_sequences(train_is, padding='post')

# %%
# We create the training set structure
IDs_test = test_data.index.unique()

test_sentences = []
test_tags = []
test_Ns = []
test_os = []
test_bs = []
test_is = []

# For each id
for i in IDs_test:
    # We extract the respective data
    sel = test_data.loc[i]
    # A sentence is a list of tokens
    sentence = sel.tokens.values 
    tag = sel['ner_ids'].values
    o = sel['o']
    b = sel['b']
    i = sel['i']

    sen_size = sentence.shape[0]

    if sen_size>si:
      while(sen_size>si):
        # We store the sentences in a list
        test_sentences.append(np.array(sentence[:si]))
        # We do the same with the tags  
        test_tags.append(np.array(tag[:si]))            
        test_os.append(np.array(o[:si]))
        test_bs.append(np.array(b[:si]))
        test_is.append(np.array(i[:si]))
        # And store the length of the sentence
        test_Ns.append(si)
        sentence = sentence[si:]
        tag = tag[si:]
        o = o[si:]
        b = b[si:]
        i = i[si:]
        sen_size = sentence.shape[0]
      
      # adding the last sentence and tag
      test_sentences.append(np.array(sentence))
      test_tags.append(np.array(tag))            
      test_os.append(np.array(o))
      test_bs.append(np.array(b))
      test_is.append(np.array(i))
      test_Ns.append(sentence.shape[0])

    # adding the last sentence and tags
    else:
      test_sentences.append(np.array(sentence))
      test_tags.append(np.array(tag))
      test_os.append(np.array(o[:si]))
      test_bs.append(np.array(b[:si]))
      test_is.append(np.array(i[:si]))
      test_Ns.append(sentence.shape[0])

# %%
# We transform everything into np arrays    
test_Ns = np.array(test_Ns)
test_sentences = np.array(test_sentences)
test_tags = np.array(test_tags)
test_os = np.array(test_os)
test_bs = np.array(test_bs)
test_is = np.array(test_is)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   import sys

# %%
# For simplicity, we create a padded array beforehand
test_sentences_padded = tf.keras.preprocessing.sequence.pad_sequences(test_sentences, padding='post')
test_tags_padded = tf.keras.preprocessing.sequence.pad_sequences(test_tags, padding='post')
# here we have 1 describing tags which are not o and 2 describing tags which are o. 0 represents padding
test_os_padded = tf.keras.preprocessing.sequence.pad_sequences(test_os + 1, padding='post')
test_bs_padded = tf.keras.preprocessing.sequence.pad_sequences(test_bs, padding='post')
test_is_padded = tf.keras.preprocessing.sequence.pad_sequences(test_is, padding='post')

# %%
# having a quick look at the shapes of the arrays created above
print(IDs_test.shape, test_Ns.shape, test_sentences.shape, test_tags.shape, test_os.shape, test_bs.shape, test_is.shape)
# Out:
# (351,) (2399,) (2399,) (2399,) (2399,) (2399,) (2399,)

# %%
# Defining vocab_size
vocab_size = len(tokenizer.word_counts)

# %%
# Changing the value of tags[0] to match the NER_ids we have defined
tags[0] = tags[0].values + 1

# %% [markdown]
# ### Manage imbalance of 'o' and not 'o' tags

# %%
# count the number of tokens which belong to the category
# Having a quick look at the distribution of the data
print("The number of o tokens : ",len(train_os_padded[train_os_padded==2]))
print("The number of not o tokens : ",len(train_os_padded[train_os_padded==1]))
print("The number of padding tokens : ",len(train_os_padded[train_os_padded==0]))
plt.bar(['padding','not o','o'],height=[len(train_os_padded[train_os_padded==0]),len(train_os_padded[train_os_padded==1]),len(train_os_padded[train_os_padded==2])])
plt.title("Distribution of O accross tags")
plt.show()
# Out:
# The number of o tokens :  373897
# The number of not o tokens :  80498
# The number of padding tokens :  34555

# %%
train_data.head()
# Out:
#                     bibcode  label_studio_id ner_ids ner_tags   section  \
# Unit #
# 1092    2021ApJ...913..130H              609      63        O  fulltext
# 1092    2021ApJ...913..130H              609      63        O  fulltext
# 1092    2021ApJ...913..130H              609      63        O  fulltext
# 1092    2021ApJ...913..130H              609      63        O  fulltext
# 1092    2021ApJ...913..130H              609      63        O  fulltext
#
#         tokens                         unique_id  b  i  o
# Unit #
# 1092       386  fulltext_609_2021ApJ...913..130H  0  0  1
# 1092        86  fulltext_609_2021ApJ...913..130H  0  0  1
# 1092      2633  fulltext_609_2021ApJ...913..130H  0  0  1
# 1092         6  fulltext_609_2021ApJ...913..130H  0  0  1
# 1092       697  fulltext_609_2021ApJ...913..130H  0  0  1

# %% [markdown]
# We have to manage this imbalance. We will do creating a new corpus with equal number of o and not o tokens.

# %%
print(" Our model has ",len(set(train_data[train_data.o==1].tokens))," unique words with the 'o'.")
# Out:
#  Our model has  22561  unique words with the 'o'.

# %% [markdown]
# **We will select each word atleast once in our training data.
#  We are doing this to reduce the probability of picking more stop words**

# %%
import random
indexes_of_o = np.array(np.where((train_os_padded).reshape(-1,)==2))
unique_tokens_in_o = list(set(train_data[train_data.o==1].tokens))
train_sentences_1d = list(train_sentences_padded.reshape(-1,))

# %%
# We now randomly pick 57937 tokens so that we have the same number of tokens as not o tokens
tokens_picked = random.sample(list(train_data[train_data.o==1].tokens.values),57937)

# %%
# We want to ensure all the unique values of tokens are picked atleast once
# We are making sure that every value is added to the new sample atleast once
new_sample = []
got_them = []
for i,j in zip(train_sentences_padded,train_os_padded):
  temp = []
  for token,o in zip(i,j):
    if o == 2:
      if token not in got_them:
        temp.append(token)
        got_them.append(token)
      else:
        temp.append(0)
    else:
      temp.append(token)
  new_sample.append(temp)

# %%
# converting the new sample to an array
new_sample = np.array(new_sample)

# %%
# finding locations in the new sample which we can randomly select to add values
# These are values with 'o' tag at a location where values are zero in the new sample
find_index = []
row = 0
for j,k in zip(train_os_padded,new_sample):
  column = 0
  for m,n in zip(j,k):
    if m == 2 and n==0:
      find_index.append((row,column))
    column +=1
  row+=1

# %%
# We now randomly pick 57937 tokens so that we have the same number of tokens as not o tokens
tokens_picked = random.sample(find_index,57937)

# %%
# Adding the values for particular locations
for i,j in tokens_picked:
  new_sample[i][j] = train_sentences_padded[i][j]

# %%
# Adjusting the tags to match the new sample
new_tags_padded = []
to_keep = (new_sample!=0).astype(int)
for i,j in zip(train_os_padded,to_keep):
  temp = [k*l for k,l in zip(i,j)]
  new_tags_padded.append(temp)

# %%
# converting our new sample to arrays
new_sample = np.array(new_sample)
new_tags_padded = np.array(new_tags_padded)

# %%
# having a quick look at the shapes of input and output for our first model
print(new_sample.shape, new_tags_padded.shape)
# Out:
# (9779, 50) (9779, 50)

# %% [markdown]
# ### Model 1 :
# The purpose of this model is to classify the tokens as o or not o

# %%
tf.keras.backend.clear_session()
sentence_input1 = tf.keras.Input(shape=(None,), name='sentence_input')

word_embedding = tf.keras.layers.Embedding(input_dim=vocab_size+1, output_dim=30, 
                    name='word_embedding', mask_zero=True)
masked_embedding = word_embedding(sentence_input1)

lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, return_sequences=True))
hf_1 = lstm1(masked_embedding)

lstm2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, return_sequences=True))
hf = lstm2(hf_1)

hf_z = tf.keras.layers.add([hf, hf_1])

dense = tf.keras.layers.Dense(4, activation='softmax')
output = dense(hf_z)

model = tf.keras.Model(inputs=sentence_input1, outputs=output, name='simpleRNN')
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics = 'accuracy')

# %%
tf.keras.utils.plot_model(model,show_shapes=True, show_dtype=True,show_layer_names=True,show_layer_activations=True)

# %%
# fitting the model. We have saved the weights for easier access.
mc = ModelCheckpoint('/content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_accuracy', verbose=1, patience=3)
history = model.fit(new_sample,new_tags_padded, validation_split = 0.2, epochs=150,callbacks=[mc,es], batch_size=1024, verbose=2)
# Out:
# Epoch 1/150
#
# Epoch 1: val_accuracy improved from -inf to 0.50912, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 22s - loss: 0.4209 - accuracy: 0.4681 - val_loss: 0.2720 - val_accuracy: 0.5091 - 22s/epoch - 3s/step
# Epoch 2/150
#
# Epoch 2: val_accuracy improved from 0.50912 to 0.68944, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.2541 - accuracy: 0.5281 - val_loss: 0.1931 - val_accuracy: 0.6894 - 4s/epoch - 514ms/step
# Epoch 3/150
#
# Epoch 3: val_accuracy improved from 0.68944 to 0.70174, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.2095 - accuracy: 0.6681 - val_loss: 0.1807 - val_accuracy: 0.7017 - 4s/epoch - 509ms/step
# Epoch 4/150
#
# Epoch 4: val_accuracy improved from 0.70174 to 0.71135, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.1965 - accuracy: 0.6997 - val_loss: 0.1761 - val_accuracy: 0.7114 - 4s/epoch - 510ms/step
# Epoch 5/150
#
# Epoch 5: val_accuracy improved from 0.71135 to 0.72657, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.1876 - accuracy: 0.7194 - val_loss: 0.1697 - val_accuracy: 0.7266 - 4s/epoch - 515ms/step
# Epoch 6/150
#
# Epoch 6: val_accuracy improved from 0.72657 to 0.74113, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.1774 - accuracy: 0.7411 - val_loss: 0.1623 - val_accuracy: 0.7411 - 4s/epoch - 513ms/step
# Epoch 7/150
#
# Epoch 7: val_accuracy improved from 0.74113 to 0.75628, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.1631 - accuracy: 0.7670 - val_loss: 0.1536 - val_accuracy: 0.7563 - 4s/epoch - 501ms/step
# Epoch 8/150
#
# Epoch 8: val_accuracy improved from 0.75628 to 0.78944, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.1473 - accuracy: 0.7999 - val_loss: 0.1393 - val_accuracy: 0.7894 - 4s/epoch - 510ms/step
# Epoch 9/150
#
# Epoch 9: val_accuracy improved from 0.78944 to 0.81604, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.1311 - accuracy: 0.8280 - val_loss: 0.1270 - val_accuracy: 0.8160 - 4s/epoch - 504ms/step
# Epoch 10/150
#
# Epoch 10: val_accuracy improved from 0.81604 to 0.84339, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.1123 - accuracy: 0.8602 - val_loss: 0.1113 - val_accuracy: 0.8434 - 4s/epoch - 504ms/step
# Epoch 11/150
#
# Epoch 11: val_accuracy improved from 0.84339 to 0.86332, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.0929 - accuracy: 0.8910 - val_loss: 0.0985 - val_accuracy: 0.8633 - 4s/epoch - 504ms/step
# Epoch 12/150
#
# Epoch 12: val_accuracy improved from 0.86332 to 0.87605, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 5s - loss: 0.0753 - accuracy: 0.9149 - val_loss: 0.0910 - val_accuracy: 0.8761 - 5s/epoch - 582ms/step
# Epoch 13/150
#
# Epoch 13: val_accuracy improved from 0.87605 to 0.88113, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.0618 - accuracy: 0.9337 - val_loss: 0.0875 - val_accuracy: 0.8811 - 4s/epoch - 508ms/step
# Epoch 14/150
#
# Epoch 14: val_accuracy improved from 0.88113 to 0.88331, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.0520 - accuracy: 0.9457 - val_loss: 0.0878 - val_accuracy: 0.8833 - 4s/epoch - 510ms/step
# Epoch 15/150
#
# Epoch 15: val_accuracy improved from 0.88331 to 0.89101, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_1_elmo_try_last.h5
# 8/8 - 4s - loss: 0.0450 - accuracy: 0.9537 - val_loss: 0.0850 - val_accuracy: 0.8910 - 4s/epoch - 513ms/step
# Epoch 16/150
#
# Epoch 16: val_accuracy did not improve from 0.89101
# 8/8 - 4s - loss: 0.0400 - accuracy: 0.9593 - val_loss: 0.0863 - val_accuracy: 0.8907 - 4s/epoch - 530ms/step
# Epoch 17/150
#
# Epoch 17: val_accuracy did not improve from 0.89101
# 8/8 - 5s - loss: 0.0357 - accuracy: 0.9640 - val_loss: 0.0896 - val_accuracy: 0.8892 - 5s/epoch - 569ms/step
# Epoch 18/150
#
# Epoch 18: val_accuracy did not improve from 0.89101
# 8/8 - 4s - loss: 0.0314 - accuracy: 0.9691 - val_loss: 0.0921 - val_accuracy: 0.8897 - 4s/epoch - 487ms/step
# Epoch 18: early stopping

# %%
# accuracy
fig = plt.figure(figsize=(10,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model 1 accuracy', fontsize=18)
plt.ylabel('Accuracy', fontsize=15)
plt.xlabel('epoch', fontsize=15)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# predicting on our train and test data
preds_train = model.predict(train_sentences_padded)
preds = model.predict(test_sentences_padded)

# %%
# creating a function which returns arrays after finding argmax
def find_argmax(preds_1):
  preds_1_arr = []
  for record in preds_1:
    temp = []
    for words in record:
      temp.append(np.argmax(np.array(words)))
    preds_1_arr.append(temp)
  return preds_1_arr

# %%
# structuring our predictions
preds_arr = find_argmax(preds)
preds_train_arr = find_argmax(preds_train)

# %%
# Defining a function to convert an array to without padding
def convert_to_without_padding(preds_1_train_arr,train_Ns):
  prediction_without_padding_train_1 = []
  for pre,ori_si in zip(preds_1_train_arr,train_Ns):
    prediction_without_padding_train_1.append(np.array(pre[:ori_si]))
  return np.array(prediction_without_padding_train_1)

# %%
# converting our predictions and true variables to without padding
# We are doing this to create a confusion matrix
prediction_without_padding_train = convert_to_without_padding(preds_train_arr,train_Ns)
prediction_without_padding_test = convert_to_without_padding(preds_arr,test_Ns)
true_without_padding_train = train_os + 1
true_without_padding_test = test_os + 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# convert to 1D
def convert_to_1D(prediction_without_padding_test):
  prediction_without_padding_test_flatten = []
  for i in prediction_without_padding_test:
    prediction_without_padding_test_flatten += list(i)
  return np.array(prediction_without_padding_test_flatten)

# %%
# converting to 1D
prediction_without_padding_train_flatten = convert_to_1D(prediction_without_padding_train)
prediction_without_padding_test_flatten = convert_to_1D(prediction_without_padding_test)
true_without_padding_train_flatten = convert_to_1D(true_without_padding_train)
true_without_padding_test_flatten = convert_to_1D(true_without_padding_test)

# %%
prediction_without_padding_train_flatten.shape, prediction_without_padding_test_flatten.shape,true_without_padding_train_flatten.shape,true_without_padding_test_flatten.shape
# Out:
# ((454395,), (111155,), (454395,), (111155,))

# %%
def create_confusion_matrix(true_without_padding_train_flatten,prediction_without_padding_train_flatten,s):
  cf_matrix = confusion_matrix(true_without_padding_train_flatten,prediction_without_padding_train_flatten)
  ax = sns.heatmap(cf_matrix,annot=True, fmt='', cmap='Blues')
  ax.set_title(s);
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values ');
  ax.xaxis.set_ticklabels(['not o','o'])
  ax.yaxis.set_ticklabels(['not o','o'])
  plt.show()

# %%
create_confusion_matrix(true_without_padding_train_flatten,prediction_without_padding_train_flatten,'Training Data\n\n')

# %%
create_confusion_matrix(true_without_padding_test_flatten,prediction_without_padding_test_flatten,'Test Data\n\n')

# %% [markdown]
# We see an improvement from our baseline model. In this case, we have less biased model.

# %%
# saving our results so far
intermediate_prediction_training_data = []
for i_s in prediction_without_padding_train:
  temp = []
  for i in i_s:
    if i==2:
      temp.append(63)
    else:
      temp.append(np.nan)
  intermediate_prediction_training_data.append(temp)

# %%
intermediate_prediction_testing_data = []
for i_s in prediction_without_padding_test:
  temp = []
  for i in i_s:
    if i==2:
      temp.append(63)
    else:
      temp.append(np.nan)
  intermediate_prediction_testing_data.append(temp)

# %% [markdown]
# ### Model 2:</br>

# %% [markdown]
# This model will take the prediction from the first model and the tokens as well. By doing this essentially we want to flag the tokens which are not outside. this way we want to see if the model can predict better. This model will try to predict if the not 'o' tag is i or b.

# %%
# Here we are defining a function that will mask those values which has been classified into a specific category before
def dot_not_fun(prediction_without_padding_train,train_sentences):
  do_ot = []
  for pred,sentence in zip(prediction_without_padding_train,train_sentences):
    do_ot.append([np.dot(i,j) for i,j in zip(np.logical_not(pred).astype(int),sentence)])
  return np.array(do_ot)

# %%
# masking 'o' tag values
dot_not = dot_not_fun((prediction_without_padding_train - 1),train_sentences)
dot_not_test = dot_not_fun((prediction_without_padding_test - 1),test_sentences)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# defining the input for the next model
input_2 = np.array(dot_not)
input_2_padded = tf.keras.preprocessing.sequence.pad_sequences(input_2, padding='post')

input_2_test = np.array(dot_not_test)
input_2_test_padded = tf.keras.preprocessing.sequence.pad_sequences(input_2_test, padding='post')

# %%
prediction_without_padding_train.shape, input_2.shape, input_2_padded.shape
# Out:
# ((9779,), (9779,), (9779, 50))

# %%
b_or_i_or_none = []
for i_s,b_s in zip(train_is,train_bs):
  temp = []
  for i,b in zip(i_s,b_s):
    if i==0 and b==0:
      temp.append(0)
    elif i==0 and b==1:
      temp.append(1)
    else:
      temp.append(2)
  b_or_i_or_none.append(np.array(temp))

# %%
# Here we have defined b as 1, i as 2 and o as 0
# Defining the training output
b_or_i_or_none = []
for i_s,b_s in zip(train_is,train_bs):
  temp = []
  for i,b in zip(i_s,b_s):
    if i==0 and b==0:
      temp.append(0)
    elif i==0 and b==1:
      temp.append(1)
    else:
      temp.append(2)
  b_or_i_or_none.append(np.array(temp))

b_or_i_or_none = np.array(b_or_i_or_none)
output_2_padded = tf.keras.preprocessing.sequence.pad_sequences(b_or_i_or_none, padding='post')

# Defining the testing output
b_or_i_or_none_test = []
for i_s,b_s in zip(test_is,test_bs):
  temp = []
  for i,b in zip(i_s,b_s):
    if i==0 and b==0:
      temp.append(0)
    elif i==0 and b==1:
      temp.append(1)
    else:
      temp.append(2)
  b_or_i_or_none_test.append(np.array(temp))

b_or_i_or_none_test = np.array(b_or_i_or_none_test)
output_2_padded_test = tf.keras.preprocessing.sequence.pad_sequences(b_or_i_or_none_test, padding='post')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
test_is.shape, test_bs.shape
# Out:
# ((2399,), (2399,))

# %%
output_2_padded.shape, output_2_padded_test.shape
# Out:
# ((9779, 50), (2399, 50))

# %%
# count the number of tokens which belong to the category
# Having a quick look at the distribution of the data
print("The number of i tokens : ",len(output_2_padded[output_2_padded==2]))
print("The number of b tokens : ",len(output_2_padded[output_2_padded==1]))
print("The number of padding tokens : ",len(output_2_padded[output_2_padded==0]))
plt.bar(['padding','b','i'],height=[len(output_2_padded[output_2_padded==0]),len(output_2_padded[output_2_padded==1]),len(output_2_padded[output_2_padded==2])])
plt.title("Distribution of b and i accross tags")
plt.show()
# Out:
# The number of i tokens :  47348
# The number of b tokens :  33150
# The number of padding tokens :  408452

# %%
print(" Our model has ",len(set(train_data[train_data.i==1].tokens))," unique words with the tag i.")
# Out:
#  Our model has  8672  unique words.

# %% [markdown]
# **We will select each word atleast once in our training data.
#  We are doing this to reduce the probability of picking more stop words**

# %%
import random
indexes_of_i = np.array(np.where((output_2_padded).reshape(-1,)==2))
unique_tokens_in_i = list(set(train_data[train_data.i==1].tokens))
train_sentences_1d = list(train_sentences_padded.reshape(-1,))

# %%
# We now randomly pick 57937 tokens so that we have the same number of tokens as b tokens
tokens_picked = random.sample(list(train_data[train_data.i==1].tokens.values),24478)

# %%
# We want to ensure all the unique values of tokens are picked atleast once
# We are making sure that every value is added to the new sample atleast once
new_sample = []
got_them = []
for i,j in zip(train_sentences_padded,output_2_padded):
  temp = []
  for token,o in zip(i,j):
    if o == 2:
      if token not in got_them:
        temp.append(token)
        got_them.append(token)
      else:
        temp.append(0)
    else:
      temp.append(token)
  new_sample.append(temp)

# %%
# converting the new sample to an array
new_sample = np.array(new_sample)

# %%
# finding locations in the new sample which we can randomly select to add values
# These are values with 'b' tag at a location where values are zero in the new sample
find_index = []
row = 0
for j,k in zip(output_2_padded,new_sample):
  column = 0
  for m,n in zip(j,k):
    if m == 2 and n==0:
      find_index.append((row,column))
    column +=1
  row+=1

# %%
# We now randomly pick 24478 tokens so that we have the same number of tokens as not b tokens
tokens_picked = random.sample(find_index,24478)

# %%
# Adding the values for particular locations
for i,j in tokens_picked:
  new_sample[i][j] = train_sentences_padded[i][j]

# %%
# Adjusting the tags to match the new sample
new_tags_padded = []
to_keep = (new_sample!=0).astype(int)
for i,j in zip(output_2_padded,to_keep):
  temp = [k*l for k,l in zip(i,j)]
  new_tags_padded.append(temp)

# %%
# converting our new sample to arrays
new_sample = np.array(new_sample)
new_tags_padded = np.array(new_tags_padded)

# %%
# having a quick look at the shapes of input and output for our first model
print(new_sample.shape, new_tags_padded.shape)
# Out:
# (9779, 50) (9779, 50)

# %%
# count the number of tokens which belong to the category
# Having a quick look at the distribution of the data
print("The number of i tokens : ",len(new_tags_padded[new_tags_padded==2]))
print("The number of b tokens : ",len(new_tags_padded[new_tags_padded==1]))
print("The number of padding tokens : ",len(new_tags_padded[new_tags_padded==0]))
plt.bar(['padding','b','i'],height=[len(new_tags_padded[new_tags_padded==0]),len(new_tags_padded[new_tags_padded==1]),len(new_tags_padded[new_tags_padded==2])])
plt.title("Distribution of b and i accross tags")
plt.show()
# Out:
# The number of i tokens :  33150
# The number of b tokens :  33150
# The number of padding tokens :  422650

# %%
input_2_padded = new_sample
output_2_padded = new_tags_padded

# %%
input_2_padded.shape,output_2_padded.shape
# Out:
# ((9779, 50), (9779, 50))

# %%
tf.keras.backend.clear_session()

sentence_input1 = tf.keras.Input(shape=(None,), name='dot_not_sentence_input')

word_embedding = tf.keras.layers.Embedding(input_dim=vocab_size+1, output_dim=30, 
                    name='word_embedding', mask_zero=True)
masked_embedding = word_embedding(sentence_input1)

lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, return_sequences=True))
hf_1 = lstm1(masked_embedding)

lstm2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, return_sequences=True))
hf = lstm2(hf_1)

hf_z = tf.keras.layers.add([hf, hf_1])

dense = tf.keras.layers.Dense(3, activation='softmax')
output = dense(hf_z)

model_2 = tf.keras.Model(inputs=sentence_input1, outputs=output, name='simpleRNN')
model_2.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics = 'accuracy')

# %%
tf.keras.utils.plot_model(model_2,show_shapes=True, show_dtype=True,show_layer_names=True,show_layer_activations=True)

# %%
# fitting the model. We have saved the weights for easier access.
mc = ModelCheckpoint('/content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_accuracy', verbose=1, patience=3)
history = model_2.fit(input_2_padded,output_2_padded, validation_split = 0.2, epochs=200,callbacks=[mc,es], batch_size=1024, verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 1: val_accuracy improved from -inf to 0.85782, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 23s - loss: 0.7988 - accuracy: 0.7820 - val_loss: 0.5353 - val_accuracy: 0.8578 - 23s/epoch - 3s/step
# Epoch 2/200
#
# Epoch 2: val_accuracy did not improve from 0.85782
# 8/8 - 5s - loss: 0.5070 - accuracy: 0.8473 - val_loss: 0.4694 - val_accuracy: 0.8578 - 5s/epoch - 658ms/step
# Epoch 3/200
#
# Epoch 3: val_accuracy did not improve from 0.85782
# 8/8 - 4s - loss: 0.4623 - accuracy: 0.8473 - val_loss: 0.4310 - val_accuracy: 0.8578 - 4s/epoch - 497ms/step
# Epoch 4/200
#
# Epoch 4: val_accuracy improved from 0.85782 to 0.85890, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.4310 - accuracy: 0.8473 - val_loss: 0.4032 - val_accuracy: 0.8589 - 4s/epoch - 535ms/step
# Epoch 5/200
#
# Epoch 5: val_accuracy improved from 0.85890 to 0.85981, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.3978 - accuracy: 0.8486 - val_loss: 0.3786 - val_accuracy: 0.8598 - 4s/epoch - 491ms/step
# Epoch 6/200
#
# Epoch 6: val_accuracy improved from 0.85981 to 0.86223, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.3745 - accuracy: 0.8501 - val_loss: 0.3581 - val_accuracy: 0.8622 - 4s/epoch - 494ms/step
# Epoch 7/200
#
# Epoch 7: val_accuracy improved from 0.86223 to 0.86436, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.3502 - accuracy: 0.8555 - val_loss: 0.3391 - val_accuracy: 0.8644 - 4s/epoch - 510ms/step
# Epoch 8/200
#
# Epoch 8: val_accuracy improved from 0.86436 to 0.86934, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.3241 - accuracy: 0.8620 - val_loss: 0.3176 - val_accuracy: 0.8693 - 4s/epoch - 497ms/step
# Epoch 9/200
#
# Epoch 9: val_accuracy improved from 0.86934 to 0.87558, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.2989 - accuracy: 0.8700 - val_loss: 0.2984 - val_accuracy: 0.8756 - 4s/epoch - 495ms/step
# Epoch 10/200
#
# Epoch 10: val_accuracy improved from 0.87558 to 0.88103, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.2726 - accuracy: 0.8784 - val_loss: 0.2800 - val_accuracy: 0.8810 - 4s/epoch - 491ms/step
# Epoch 11/200
#
# Epoch 11: val_accuracy improved from 0.88103 to 0.88754, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.2474 - accuracy: 0.8872 - val_loss: 0.2644 - val_accuracy: 0.8875 - 4s/epoch - 507ms/step
# Epoch 12/200
#
# Epoch 12: val_accuracy improved from 0.88754 to 0.89463, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.2231 - accuracy: 0.8981 - val_loss: 0.2505 - val_accuracy: 0.8946 - 4s/epoch - 496ms/step
# Epoch 13/200
#
# Epoch 13: val_accuracy improved from 0.89463 to 0.90246, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.1970 - accuracy: 0.9108 - val_loss: 0.2340 - val_accuracy: 0.9025 - 4s/epoch - 530ms/step
# Epoch 14/200
#
# Epoch 14: val_accuracy improved from 0.90246 to 0.90757, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.1805 - accuracy: 0.9208 - val_loss: 0.2278 - val_accuracy: 0.9076 - 4s/epoch - 499ms/step
# Epoch 15/200
#
# Epoch 15: val_accuracy improved from 0.90757 to 0.91228, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.1595 - accuracy: 0.9314 - val_loss: 0.2271 - val_accuracy: 0.9123 - 4s/epoch - 488ms/step
# Epoch 16/200
#
# Epoch 16: val_accuracy improved from 0.91228 to 0.91521, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 5s - loss: 0.1418 - accuracy: 0.9419 - val_loss: 0.2389 - val_accuracy: 0.9152 - 5s/epoch - 587ms/step
# Epoch 17/200
#
# Epoch 17: val_accuracy improved from 0.91521 to 0.91839, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.1281 - accuracy: 0.9494 - val_loss: 0.2261 - val_accuracy: 0.9184 - 4s/epoch - 499ms/step
# Epoch 18/200
#
# Epoch 18: val_accuracy improved from 0.91839 to 0.91913, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.1190 - accuracy: 0.9532 - val_loss: 0.2372 - val_accuracy: 0.9191 - 4s/epoch - 491ms/step
# Epoch 19/200
#
# Epoch 19: val_accuracy improved from 0.91913 to 0.91968, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_2_elmo_try.h5
# 8/8 - 4s - loss: 0.1112 - accuracy: 0.9559 - val_loss: 0.2383 - val_accuracy: 0.9197 - 4s/epoch - 502ms/step
# Epoch 20/200
#
# Epoch 20: val_accuracy did not improve from 0.91968
# 8/8 - 4s - loss: 0.1061 - accuracy: 0.9579 - val_loss: 0.2519 - val_accuracy: 0.9180 - 4s/epoch - 484ms/step
# Epoch 21/200
#
# Epoch 21: val_accuracy did not improve from 0.91968
# 8/8 - 4s - loss: 0.1021 - accuracy: 0.9593 - val_loss: 0.2497 - val_accuracy: 0.9187 - 4s/epoch - 492ms/step
# Epoch 22/200
#
# Epoch 22: val_accuracy did not improve from 0.91968
# 8/8 - 4s - loss: 0.0994 - accuracy: 0.9605 - val_loss: 0.2584 - val_accuracy: 0.9187 - 4s/epoch - 492ms/step
# Epoch 22: early stopping

# %%
# accuracy
fig = plt.figure(figsize=(10,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model 2 accuracy', fontsize=18)
plt.ylabel('Accuracy', fontsize=15)
plt.xlabel('epoch', fontsize=15)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# Predicting using our model
preds_train_1 = model_2.predict(train_sentences_padded)
preds_1 = model_2.predict(test_sentences_padded)

# %%
# structuring our predictions
preds_1_arr = find_argmax(preds_1)
preds_1_train_arr = find_argmax(preds_train_1)

# %%
# converting our predictions and true variables to without padding
# We are doing this to create a confusion matrix
prediction_without_padding_train_1 = convert_to_without_padding(preds_1_train_arr,train_Ns)
prediction_without_padding_test_1 = convert_to_without_padding(preds_1_arr,test_Ns)
true_without_padding_train_1 = b_or_i_or_none
true_without_padding_test_1 = b_or_i_or_none_test
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# converting to 1D
prediction_without_padding_train_flatten_1 = convert_to_1D(prediction_without_padding_train_1)
prediction_without_padding_test_flatten_1 = convert_to_1D(prediction_without_padding_test_1)
true_without_padding_train_flatten_1 = convert_to_1D(true_without_padding_train_1)
true_without_padding_test_flatten_1 = convert_to_1D(true_without_padding_test_1)

# %%
def create_confusion_matrix(true_without_padding_train_flatten,prediction_without_padding_train_flatten,s):
  cf_matrix = confusion_matrix(true_without_padding_train_flatten,prediction_without_padding_train_flatten)
  ax = sns.heatmap(cf_matrix,annot=True, fmt='', cmap='Blues')
  ax.set_title(s);
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values ');
  ax.xaxis.set_ticklabels(['padding','b','i'])
  ax.yaxis.set_ticklabels(['padding','b','i'])
  plt.show()

# %%
create_confusion_matrix(true_without_padding_train_flatten_1,prediction_without_padding_train_flatten_1,'Training Data\n\n')

# %%
create_confusion_matrix(true_without_padding_test_flatten_1,prediction_without_padding_test_flatten_1,'Testing Data\n\n')

# %%
# Creating an intermediate prediction which has 63 for 'o', 'b' and 'i' for train data
now_train = []
for i_s,j_s in zip(prediction_without_padding_train_1,intermediate_prediction_training_data):
  temp = []
  for i,j in zip(i_s,j_s):
    if j is np.nan:
      if i==1:
        temp.append('b')
      elif i== 2:
        temp.append('i')
      else:
        temp.append(63)
        # print(i,j)
    else:
      temp.append(j)
  now_train.append(temp)

# %%
# Creating an intermediate prediction which has 63 for 'o', 'b' and 'i'
now_test = []
for i_s,j_s in zip(prediction_without_padding_test_1,intermediate_prediction_testing_data):
  temp = []
  for i,j in zip(i_s,j_s):
    if j is np.nan:
      if i==1:
        temp.append('b')
      elif i== 2:
        temp.append('i')
      else:
        temp.append(63)
        # print(i,j)
    else:
      temp.append(j)
  now_test.append(temp)

# %% [markdown]
# ### Model 3: now we will categorize b tags

# %%
# creating a function which will give us the location of the b tags in our predictions
def flag_characters(now,c):
  is_only_train = []
  for i in now:
    temp = []
    for j in i:
      if j == c:
        temp.append(1)
      else:
        temp.append(0)
    is_only_train.append(temp)
  return is_only_train

# %%
# Defining the locations at which bs are predicted.
ib_only_train = flag_characters(now_train,'b')
ib_only_test = flag_characters(now_test,'b')

# %%
# Defining a function that masks tags already predicted
def mask_ip_op(is_only_train,train_sentences):
  dot_not_is = []
  for pred,sentence in zip(is_only_train,train_sentences):
    dot_not_is.append(np.array([np.dot(i,j) for i,j in zip(pred,sentence)]))
  return np.array(dot_not_is)

# %%
# Defining inputs
input_3 = mask_ip_op(ib_only_train,train_sentences)
input_3_test = mask_ip_op(ib_only_test,test_sentences)

input_3_padded = tf.keras.preprocessing.sequence.pad_sequences(input_3, padding='post')
input_3_test_padded = tf.keras.preprocessing.sequence.pad_sequences(input_3_test, padding='post')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# Defining outputs
output_3 = mask_ip_op(ib_only_train,train_tags)
output_3_test = mask_ip_op(ib_only_test,test_tags)

output_3_padded = tf.keras.preprocessing.sequence.pad_sequences(output_3, padding='post')
output_3_test_padded = tf.keras.preprocessing.sequence.pad_sequences(output_3_test, padding='post')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
input_3_padded.shape, input_3_test_padded.shape, output_3_padded.shape, output_3_test_padded.shape
# Out:
# ((9779, 50), (2399, 50), (9779, 50), (2399, 50))

# %%
# Here we have 30 categories a tag can be classified into
# 0 stands for  padding and 32 stands for others
tags[:31]
# Out:
#                         index   0
# 0                   B-Archive   1
# 1           B-CelestialObject   2
# 2     B-CelestialObjectRegion   3
# 3           B-CelestialRegion   4
# 4                  B-Citation   5
# 5             B-Collaboration   6
# 6         B-ComputingFacility   7
# 7                  B-Database   8
# 8                   B-Dataset   9
# 9    B-EntityOfFutureInterest  10
# 10                    B-Event  11
# 11               B-Fellowship  12
# 12                  B-Formula  13
# 13                    B-Grant  14
# 14               B-Identifier  15
# 15               B-Instrument  16
# 16                 B-Location  17
# 17                  B-Mission  18
# 18                    B-Model  19
# 19  B-ObservationalTechniques  20
# 20              B-Observatory  21
# 21             B-Organization  22
# 22                   B-Person  23
# 23                 B-Proposal  24
# 24                 B-Software  25
# 25                   B-Survey  26
# 26                      B-Tag  27
# 27                B-Telescope  28
# 28              B-TextGarbage  29
# 29                      B-URL  30
# 30               B-Wavelength  31

# %%
# Here we have 30 categories a tag can be classified into
# 0 stands for  padding and 32 stands for others
output_3_padded_new = []
for i in output_3_padded:
  temp = []
  for j in i:
    if j>31:
      temp.append(32)
    else:
      temp.append(j)
  output_3_padded_new.append(temp)
output_3_padded_new = np.array(output_3_padded_new)

# Here we have 30 categories a tag can be classified into
# 0 stands for  padding and 32 stands for others
output_3_padded_new_test = []
for i in output_3_test_padded:
  temp = []
  for j in i:
    if j>31:
      temp.append(32)
    else:
      temp.append(j)
  output_3_padded_new_test.append(temp)
output_3_padded_new_test = np.array(output_3_padded_new_test)

# %%
# defining masked output
output_3_padded_new.shape, output_3_padded_new_test.shape
# Out:
# ((9779, 50), (2399, 50))

# %%
count_tag = {}
for j in output_3_padded_new:
  for i in j:
    if i in count_tag.keys():
      count_tag[i] += 1
    else:
      count_tag[i] = 1

# %%
# having a quick look at the distribution of the models. 
# We have not plotted the 0 (padding) tag to have a better look at the model
plt.bar(list(count_tag.keys())[1:],list(count_tag.values())[1:])
plt.show()

# %%
print(" The minimum frequency of a tag is :",min(count_tag.values()))
# Out:
#  The minimum frequency of a tag is : 15

# %% [markdown]
# Since this is such a small number, the training data will become very small if we just consider 15x30 sample. So, we will take out outliers by taking the median of all the frequencies as the threshold and mask every value to have that threshold of frequency.

# %%
print("The median :", np.median(list(count_tag.values())))
# Out:
# The median : 252.0

# %%
def find_unique_tokens_for_tag(ch):
  unique_tokens_for_tag = []
  for i_s,j_s in zip(input_3_padded,output_3_padded_new):
    for i,j in zip(i_s,j_s):
      if j==ch:
        if i not in unique_tokens_for_tag:
          unique_tokens_for_tag.append(i)
  return unique_tokens_for_tag

# %%
masking_is_needed = []
for i in count_tag.keys():
  if count_tag[i]>=252:
    print("The ",i,"tag will has : ",count_tag[i],"So, masking is needed.")
    masking_is_needed.append(i)
# Out:
# The  0 tag will has :  458096 So, masking is needed.
# The  2 tag will has :  1848 So, masking is needed.
# The  32 tag will has :  6410 So, masking is needed.
# The  5 tag will has :  4261 So, masking is needed.
# The  13 tag will has :  1240 So, masking is needed.
# The  22 tag will has :  4400 So, masking is needed.
# The  14 tag will has :  1961 So, masking is needed.
# The  23 tag will has :  2017 So, masking is needed.
# The  17 tag will has :  823 So, masking is needed.
# The  26 tag will has :  626 So, masking is needed.
# The  21 tag will has :  564 So, masking is needed.
# The  16 tag will has :  400 So, masking is needed.
# The  28 tag will has :  977 So, masking is needed.
# The  25 tag will has :  589 So, masking is needed.
# The  31 tag will has :  1776 So, masking is needed.
# The  19 tag will has :  993 So, masking is needed.
# The  12 tag will has :  252 So, masking is needed.

# %%
for i in masking_is_needed:
  print(" Our model has ",len(find_unique_tokens_for_tag(i))," unique words with the ",i," tag")
# Out:
#  Our model has  1  unique words with the  0  tag
#  Our model has  558  unique words with the  2  tag
#  Our model has  2110  unique words with the  32  tag
#  Our model has  2768  unique words with the  5  tag
#  Our model has  170  unique words with the  13  tag
#  Our model has  870  unique words with the  22  tag
#  Our model has  1437  unique words with the  14  tag
#  Our model has  1257  unique words with the  23  tag
#  Our model has  216  unique words with the  17  tag
#  Our model has  203  unique words with the  26  tag
#  Our model has  118  unique words with the  21  tag
#  Our model has  210  unique words with the  16  tag
#  Our model has  276  unique words with the  28  tag
#  Our model has  340  unique words with the  25  tag
#  Our model has  526  unique words with the  31  tag
#  Our model has  422  unique words with the  19  tag
#  Our model has  153  unique words with the  12  tag

# %% [markdown]
# **We would have selected each word atleast once in our training data, but it is not possible to select every word atleast once for all the categories. So we will randomly pick them.**

# %%
for ch in masking_is_needed:
  n = len(find_unique_tokens_for_tag(ch))
  indexes_of_o = np.array(np.where((output_3_padded_new).reshape(-1,)==ch))
  unique_tokens_in_o = list(find_unique_tokens_for_tag(ch))
  train_sentences_1d = list(input_3_padded.reshape(-1,))

  # We want to ensure all the unique values of tokens are picked atleast once
  # We are making sure that every value is added to the new sample atleast once
  new_sample = []
  got_them = []
  for i,j in zip(input_3_padded,output_3_padded_new):
    temp = []
    for token,o in zip(i,j):
      if o == ch:
        if token not in got_them and len(got_them)>=252:
          temp.append(token)
          got_them.append(token)
        else:
          temp.append(0)
      else:
        temp.append(token)
    new_sample.append(temp)
  
  # converting the new sample to an array
  new_sample = np.array(new_sample)

  if not len(got_them)==252:
    # finding locations in the new sample which we can randomly select to add values
    # These are values with ch tag at a location where values are zero in the new sample
    find_index = []
    row = 0
    for j,k in zip(output_3_padded_new,new_sample):
      column = 0
      for m,n in zip(j,k):
        if m == ch and n==0:
          find_index.append((row,column))
        column +=1
      row+=1
    
    try:
      tokens_picked = random.sample(find_index,252-n)
    except:
      ;
    
    # Adding the values for particular locations
    for i,j in tokens_picked:
      new_sample[i][j] = input_3_padded[i][j]
    
  # Adjusting the tags to match the new sample
  new_tags_padded = []
  to_keep = (new_sample!=0).astype(int)
  for i,j in zip(output_3_padded_new,to_keep):
    temp = [k*l for k,l in zip(i,j)]
    new_tags_padded.append(temp)

  # converting our new sample to arrays
  new_sample = np.array(new_sample)
  new_tags_padded = np.array(new_tags_padded)
  
  output_3_padded_new = new_tags_padded
  input_3_padded = new_sample

# %%
count_tag = {}
for j in output_3_padded_new:
  for i in j:
    if i in count_tag.keys():
      count_tag[i] += 1
    else:
      count_tag[i] = 1

# %%
# having a quick look at the distribution of the models. 
# We have not plotted the 0 (padding) tag to have a better look at the model
plt.bar(list(count_tag.keys())[1:],list(count_tag.values())[1:])
plt.show()

# %%
tf.keras.backend.clear_session()
sentence_input1 = tf.keras.Input(shape=(None,), name='sentence_input')

word_embedding = tf.keras.layers.Embedding(input_dim=vocab_size+1, output_dim=30, 
                    name='word_embedding', mask_zero=True)
masked_embedding = word_embedding(sentence_input1)

lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, return_sequences=True))
hf_1 = lstm1(masked_embedding)

lstm2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, return_sequences=True))
hf = lstm2(hf_1)

hf_z = tf.keras.layers.add([hf, hf_1])

dense = tf.keras.layers.Dense(33, activation='softmax')
output = dense(hf_z)

model_3 = tf.keras.Model(inputs=sentence_input1, outputs=output, name='simpleRNN')
model_3.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics = 'accuracy')

# %%
tf.keras.utils.plot_model(model_3,show_shapes=True, show_dtype=True,show_layer_names=True,show_layer_activations=True)

# %%
# fitting the model. We have saved the weights for easier access.
mc = ModelCheckpoint('/content/drive/MyDrive/AI-3/project/weights_hemanis_model_3_elmo_try.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_accuracy', verbose=1, patience=3)
history = model_3.fit(input_3_padded,output_3_padded_new, validation_split = 0.2, epochs=200,callbacks=[mc,es], batch_size=1024, verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 1: val_accuracy improved from -inf to 0.06821, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_3_elmo_try.h5
# 8/8 - 24s - loss: 0.0444 - accuracy: 0.0461 - val_loss: 0.0277 - val_accuracy: 0.0682 - 24s/epoch - 3s/step
# Epoch 2/200
#
# Epoch 2: val_accuracy did not improve from 0.06821
# 8/8 - 4s - loss: 0.0442 - accuracy: 0.0577 - val_loss: 0.0276 - val_accuracy: 0.0631 - 4s/epoch - 505ms/step
# Epoch 3/200
#
# Epoch 3: val_accuracy improved from 0.06821 to 0.07207, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_3_elmo_try.h5
# 8/8 - 4s - loss: 0.0440 - accuracy: 0.0563 - val_loss: 0.0274 - val_accuracy: 0.0721 - 4s/epoch - 504ms/step
# Epoch 4/200
#
# Epoch 4: val_accuracy improved from 0.07207 to 0.07593, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_3_elmo_try.h5
# 8/8 - 4s - loss: 0.0436 - accuracy: 0.0513 - val_loss: 0.0271 - val_accuracy: 0.0759 - 4s/epoch - 514ms/step
# Epoch 5/200
#
# Epoch 5: val_accuracy did not improve from 0.07593
# 8/8 - 4s - loss: 0.0432 - accuracy: 0.0573 - val_loss: 0.0268 - val_accuracy: 0.0721 - 4s/epoch - 512ms/step
# Epoch 6/200
#
# Epoch 6: val_accuracy did not improve from 0.07593
# 8/8 - 4s - loss: 0.0427 - accuracy: 0.0684 - val_loss: 0.0265 - val_accuracy: 0.0682 - 4s/epoch - 508ms/step
# Epoch 7/200
#
# Epoch 7: val_accuracy did not improve from 0.07593
# 8/8 - 4s - loss: 0.0423 - accuracy: 0.0700 - val_loss: 0.0262 - val_accuracy: 0.0386 - 4s/epoch - 492ms/step
# Epoch 7: early stopping

# %%
# accuracy
fig = plt.figure(figsize=(10,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model 3 accuracy', fontsize=18)
plt.ylabel('Accuracy', fontsize=15)
plt.xlabel('epoch', fontsize=15)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# Predicting using our model
preds_train_3= model_3.predict(train_sentences_padded)
preds_3 = model_3.predict(test_sentences_padded)

# %%
# structuring our predictions
preds_3_arr = find_argmax(preds_3)
preds_3_train_arr = find_argmax(preds_train_3)

# %%
# converting our predictions and true variables to without padding
# We are doing this to create a confusion matrix
prediction_without_padding_train_3 = convert_to_without_padding(preds_3_train_arr,train_Ns)
prediction_without_padding_test_3 = convert_to_without_padding(preds_3_arr,test_Ns)
true_without_padding_train_3 = output_3_padded_new
true_without_padding_test_3 = output_3_padded_new_test
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# converting to 1D
prediction_without_padding_train_flatten_3 = convert_to_1D(prediction_without_padding_train_3)
prediction_without_padding_test_flatten_3 = convert_to_1D(prediction_without_padding_test_3)
true_without_padding_train_flatten_3 = convert_to_1D(true_without_padding_train_3)
true_without_padding_test_flatten_3 = convert_to_1D(true_without_padding_test_3)

# %%
# Creating an intermediate prediction which has 63 for 'o', 'b' and 'i' for train data
semi_final_train = []
for i_s,j_s in zip(prediction_without_padding_train_3,now_train):
  temp = []
  for i,j in zip(i_s,j_s):
    # print(i,j)
    if j is 'b':
      if i != 32:
        temp.append(int(i))
      else:
        temp.append(63)
    else:
      temp.append(j)
  semi_final_train.append(temp)

# %%
# Creating an intermediate prediction which has 63 for 'o', 'b' and 'i' for train data
semi_final_test = []
for i_s,j_s in zip(prediction_without_padding_test_3,now_test):
  temp = []
  for i,j in zip(i_s,j_s):
    if j is 'b':
      if i != 32:
        temp.append(int(i))
      else:
        temp.append(63)
    else:
      temp.append(j)
  semi_final_test.append(temp)

# %% [markdown]
# ### Model 4: Predicting i</br>

# %%
# Defining the locations at which is are predicted.
is_only_train = flag_characters(now_train,'i')
is_only_test = flag_characters(now_test,'i')

# %%
# Defining inputs
input_4 = mask_ip_op(is_only_train,train_sentences)
input_4_test = mask_ip_op(is_only_test,test_sentences)

input_4_padded = tf.keras.preprocessing.sequence.pad_sequences(input_4, padding='post')
input_4_test_padded = tf.keras.preprocessing.sequence.pad_sequences(input_4_test, padding='post')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# Defining outputs
output_4 = mask_ip_op(is_only_train,train_tags)
output_4_test = mask_ip_op(is_only_test,test_tags)

output_4_padded = tf.keras.preprocessing.sequence.pad_sequences(output_4, padding='post')
output_4_test_padded = tf.keras.preprocessing.sequence.pad_sequences(output_4_test, padding='post')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
input_4_padded.shape, input_4_test_padded.shape, output_4_padded.shape, output_4_test_padded.shape
# Out:
# ((9779, 50), (2399, 50), (9779, 50), (2399, 50))

# %%
tags[31:62]
# Out:
#                         index   0
# 31                  I-Archive  32
# 32          I-CelestialObject  33
# 33    I-CelestialObjectRegion  34
# 34          I-CelestialRegion  35
# 35                 I-Citation  36
# 36            I-Collaboration  37
# 37        I-ComputingFacility  38
# 38                 I-Database  39
# 39                  I-Dataset  40
# 40   I-EntityOfFutureInterest  41
# 41                    I-Event  42
# 42               I-Fellowship  43
# 43                  I-Formula  44
# 44                    I-Grant  45
# 45               I-Identifier  46
# 46               I-Instrument  47
# 47                 I-Location  48
# 48                  I-Mission  49
# 49                    I-Model  50
# 50  I-ObservationalTechniques  51
# 51              I-Observatory  52
# 52             I-Organization  53
# 53                   I-Person  54
# 54                 I-Proposal  55
# 55                 I-Software  56
# 56                   I-Survey  57
# 57                      I-Tag  58
# 58                I-Telescope  59
# 59              I-TextGarbage  60
# 60                      I-URL  61
# 61               I-Wavelength  62

# %%
count_tag_i = {}
for j in output_4_padded:
  for i in j:
    if i in count_tag_i.keys():
      count_tag_i[i] += 1
    else:
      count_tag_i[i] = 1

# %%
plt.bar(list(count_tag_i.keys())[1:],list(count_tag_i.values())[1:])
plt.show()

# %%
# Here we have 30 categories a tag can be classified into
# 0 stands for  padding and 32 stands for others
output_4_padded_new = []
for i in output_4_padded:
  temp = []
  for j in i:
    if j == 0:
      temp.append(0)
    elif j<32 or j>62:
      temp.append(32)
    else:
      temp.append(j-31)
  output_4_padded_new.append(temp)
output_4_padded_new = np.array(output_4_padded_new)  

output_4_padded_new_test = []
for i in output_4_test_padded:
  temp = []
  for j in i:
    if j == 0:
      temp.append(32)
    elif j<32 or j>62:
      temp.append(0)
    else:
      temp.append(j-31)
  output_4_padded_new_test.append(temp)
output_4_padded_new_test = np.array(output_4_padded_new_test)

# %%
output_4_padded_new.shape, output_4_padded_new_test.shape
# Out:
# ((9779, 50), (2399, 50))

# %%
print(" The minimum frequency of a tag is :",min(count_tag_i.values()))
# Out:
#  The minimum frequency of a tag is : 4

# %% [markdown]
# Since this is such a small number, the training data will become very small if we just consider 4x30 sample. So, we will take out outliers by taking the median of all the frequencies as the threshold and mask every value to have that threshold of frequency.

# %%
print("The median :", np.median(list(count_tag_i.values())))
# Out:
# The median : 81.5

# %%
def find_unique_tokens_for_tag(ch):
  unique_tokens_for_tag = []
  for i_s,j_s in zip(input_4_padded,output_4_padded_new):
    for i,j in zip(i_s,j_s):
      if j==ch:
        if i not in unique_tokens_for_tag:
          unique_tokens_for_tag.append(i)
  return unique_tokens_for_tag

# %%
masking_is_needed = []
for i in count_tag.keys():
  if count_tag[i]>=82:
    print("The ",i,"tag will has : ",count_tag[i],"So, masking is needed.")
    masking_is_needed.append(i)
# Out:
# The  0 tag will has :  483201 So, masking is needed.
# The  32 tag will has :  252 So, masking is needed.
# The  2 tag will has :  252 So, masking is needed.
# The  13 tag will has :  252 So, masking is needed.
# The  14 tag will has :  252 So, masking is needed.
# The  17 tag will has :  252 So, masking is needed.
# The  22 tag will has :  252 So, masking is needed.
# The  23 tag will has :  252 So, masking is needed.
# The  26 tag will has :  252 So, masking is needed.
# The  30 tag will has :  186 So, masking is needed.
# The  6 tag will has :  220 So, masking is needed.
# The  16 tag will has :  252 So, masking is needed.
# The  9 tag will has :  205 So, masking is needed.
# The  28 tag will has :  252 So, masking is needed.
# The  5 tag will has :  252 So, masking is needed.
# The  31 tag will has :  252 So, masking is needed.
# The  25 tag will has :  252 So, masking is needed.
# The  3 tag will has :  133 So, masking is needed.
# The  12 tag will has :  252 So, masking is needed.
# The  7 tag will has :  233 So, masking is needed.
# The  21 tag will has :  252 So, masking is needed.
# The  1 tag will has :  121 So, masking is needed.
# The  19 tag will has :  252 So, masking is needed.
# The  4 tag will has :  94 So, masking is needed.
# The  8 tag will has :  173 So, masking is needed.

# %%
for i in masking_is_needed:
  print(" Our model has ",len(find_unique_tokens_for_tag(i))," unique words with the ",i," tag")
# Out:
#  Our model has  1  unique words with the  0  tag
#  Our model has  2875  unique words with the  32  tag
#  Our model has  562  unique words with the  2  tag
#  Our model has  1061  unique words with the  13  tag
#  Our model has  826  unique words with the  14  tag
#  Our model has  91  unique words with the  17  tag
#  Our model has  1040  unique words with the  22  tag
#  Our model has  1387  unique words with the  23  tag
#  Our model has  88  unique words with the  26  tag
#  Our model has  4  unique words with the  30  tag
#  Our model has  67  unique words with the  6  tag
#  Our model has  41  unique words with the  16  tag
#  Our model has  82  unique words with the  9  tag
#  Our model has  105  unique words with the  28  tag
#  Our model has  972  unique words with the  5  tag
#  Our model has  171  unique words with the  31  tag
#  Our model has  128  unique words with the  25  tag
#  Our model has  42  unique words with the  3  tag
#  Our model has  215  unique words with the  12  tag
#  Our model has  132  unique words with the  7  tag
#  Our model has  92  unique words with the  21  tag
#  Our model has  45  unique words with the  1  tag
#  Our model has  218  unique words with the  19  tag
#  Our model has  78  unique words with the  4  tag
#  Our model has  41  unique words with the  8  tag

# %% [markdown]
# **We would have selected each word atleast once in our training data, but it is not possible to select every word atleast once for all the categories. So we will randomly pick them.**

# %%
for ch in masking_is_needed:
  n = len(find_unique_tokens_for_tag(ch))
  indexes_of_o = np.array(np.where((output_4_padded_new).reshape(-1,)==ch))
  unique_tokens_in_o = list(find_unique_tokens_for_tag(ch))
  train_sentences_1d = list(input_4_padded.reshape(-1,))

  # We want to ensure all the unique values of tokens are picked atleast once
  # We are making sure that every value is added to the new sample atleast once
  new_sample = []
  got_them = []
  for i,j in zip(input_4_padded,output_4_padded_new):
    temp = []
    for token,o in zip(i,j):
      if o == ch:
        if token not in got_them and len(got_them)>=82:
          temp.append(token)
          got_them.append(token)
        else:
          temp.append(0)
      else:
        temp.append(token)
    new_sample.append(temp)
  
  # converting the new sample to an array
  new_sample = np.array(new_sample)

  if not len(got_them)==82:
    # finding locations in the new sample which we can randomly select to add values
    # These are values with ch tag at a location where values are zero in the new sample
    find_index = []
    row = 0
    for j,k in zip(output_4_padded_new,new_sample):
      column = 0
      for m,n in zip(j,k):
        if m == ch and n==0:
          find_index.append((row,column))
        column +=1
      row+=1
    
    try:
      tokens_picked = random.sample(find_index,82-n)
    except:
      ;
    
    # Adding the values for particular locations
    for i,j in tokens_picked:
      new_sample[i][j] = input_4_padded[i][j]
    
  # Adjusting the tags to match the new sample
  new_tags_padded = []
  to_keep = (new_sample!=0).astype(int)
  for i,j in zip(output_4_padded_new,to_keep):
    temp = [k*l for k,l in zip(i,j)]
    new_tags_padded.append(temp)

  # converting our new sample to arrays
  new_sample = np.array(new_sample)
  new_tags_padded = np.array(new_tags_padded)
  
  output_4_padded_new = new_tags_padded
  input_4_padded = new_sample

# %%
count_tag = {}
for j in output_4_padded_new:
  for i in j:
    if i in count_tag.keys():
      count_tag[i] += 1
    else:
      count_tag[i] = 1

# %%
# having a quick look at the distribution of the models. 
# We have not plotted the 0 (padding) tag to have a better look at the model
plt.bar(list(count_tag.keys())[1:],list(count_tag.values())[1:])
plt.show()

# %%
tf.keras.backend.clear_session()
sentence_input1 = tf.keras.Input(shape=(None,), name='sentence_input')

word_embedding = tf.keras.layers.Embedding(input_dim=vocab_size+1, output_dim=30, 
                    name='word_embedding', mask_zero=True)
masked_embedding = word_embedding(sentence_input1)

lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, return_sequences=True))
hf_1 = lstm1(masked_embedding)

lstm2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=128, return_sequences=True))
hf = lstm2(hf_1)

hf_z = tf.keras.layers.add([hf, hf_1])

dense = tf.keras.layers.Dense(33, activation='softmax')
output = dense(hf_z)

model_4 = tf.keras.Model(inputs=sentence_input1, outputs=output, name='simpleRNN')
model_4.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics = 'accuracy')

# %%
tf.keras.utils.plot_model(model_4,show_shapes=True, show_dtype=True,show_layer_names=True,show_layer_activations=True)

# %%
# fitting the model. We have saved the weights for easier access.
mc = ModelCheckpoint('/content/drive/MyDrive/AI-3/project/weights_hemanis_model_4_elmo_try.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_accuracy', verbose=1, patience=3)
history = model_4.fit(input_4_padded,output_4_padded_new, validation_split = 0.2, epochs=200,callbacks=[mc,es], batch_size=1024, verbose=2)
# Out:
# Epoch 1/200
#
# Epoch 1: val_accuracy improved from -inf to 0.01195, saving model to /content/drive/MyDrive/AI-3/project/weights_hemanis_model_4_elmo_try.h5
# 8/8 - 26s - loss: 0.0145 - accuracy: 0.0289 - val_loss: 0.0090 - val_accuracy: 0.0120 - 26s/epoch - 3s/step
# Epoch 2/200
#
# Epoch 2: val_accuracy did not improve from 0.01195
# 8/8 - 6s - loss: 0.0145 - accuracy: 0.0548 - val_loss: 0.0089 - val_accuracy: 0.0080 - 6s/epoch - 744ms/step
# Epoch 3/200
#
# Epoch 3: val_accuracy did not improve from 0.01195
# 8/8 - 5s - loss: 0.0144 - accuracy: 0.0529 - val_loss: 0.0089 - val_accuracy: 0.0120 - 5s/epoch - 677ms/step
# Epoch 4/200
#
# Epoch 4: val_accuracy did not improve from 0.01195
# 8/8 - 4s - loss: 0.0144 - accuracy: 0.0535 - val_loss: 0.0089 - val_accuracy: 0.0120 - 4s/epoch - 488ms/step
# Epoch 4: early stopping

# %%
# accuracy
fig = plt.figure(figsize=(10,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model 4 accuracy', fontsize=18)
plt.ylabel('Accuracy', fontsize=15)
plt.xlabel('epoch', fontsize=15)
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# Predicting using our model
preds_train_4= model_4.predict(train_sentences_padded)
preds_4 = model_4.predict(test_sentences_padded)

# %%
# structuring our predictions
preds_4_arr = find_argmax(preds_4)
preds_4_train_arr = find_argmax(preds_train_4)

# %%
# converting our predictions and true variables to without padding
# We are doing this to create a confusion matrix
prediction_without_padding_train_4 = convert_to_without_padding(preds_4_train_arr,train_Ns)
prediction_without_padding_test_4 = convert_to_without_padding(preds_4_arr,test_Ns)
true_without_padding_train_4 = output_4_padded_new
true_without_padding_test_4 = output_4_padded_new_test
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# converting to 1D
prediction_without_padding_train_flatten_4 = convert_to_1D(prediction_without_padding_train_4)
prediction_without_padding_test_flatten_4 = convert_to_1D(prediction_without_padding_test_4)
true_without_padding_train_flatten_4 = convert_to_1D(true_without_padding_train_4)
true_without_padding_test_flatten_4 = convert_to_1D(true_without_padding_test_4)

# %% [markdown]
# ### Final Results

# %%
# Creating an intermediate prediction which has 63 for 'o', 'b' and 'i' for train data
final_train = []
for i_s,j_s in zip(prediction_without_padding_train_4,semi_final_train):
  temp = []
  for i,j in zip(i_s,j_s):
    if j is 'i':
      if i!=32 or i!=0:
        temp.append(i+31)
      else:
        temp.append(63)
    else:
      temp.append(j)
  final_train.append(np.array(temp))

# %%
# Creating an intermediate prediction which has 63 for 'o', 'b' and 'i' for train data
final_test = []
for i_s,j_s in zip(prediction_without_padding_test_4,semi_final_test):
  temp = []
  for i,j in zip(i_s,j_s):
    if j is 'i':
      if i!=32 or i!=0:
        temp.append(i+31)
      else:
        temp.append(63)
    else:
      temp.append(j)
  final_test.append(np.array(temp))

# %%
# Having a look at the distribution in prediction
unique, counts = np.unique(convert_to_1D(final_test), return_counts=True)

from prettytable import PrettyTable
columns=['Predictions','Tag', 'Count']
mytable = PrettyTable()
mytable.add_column(columns[0], unique)
mytable.add_column(columns[1], tags.iloc[unique-1]['index'].values)
mytable.add_column(columns[2], counts)

print(mytable)
# Out:
# +-------------+-------------------+-------+
# | Predictions |        Tag        | Count |
# +-------------+-------------------+-------+
# |      6      |  B-Collaboration  |  542  |
# |      25     |     B-Software    |   4   |
# |      30     |       B-URL       |  5289 |
# |      35     | I-CelestialRegion |  7934 |
# |      63     |         O         | 97386 |
# +-------------+-------------------+-------+

# %%
# Having a look at the distribution of prediction in test data
unique, counts = np.unique(convert_to_1D(final_train), return_counts=True)

from prettytable import PrettyTable
columns=['Predictions','Tag', 'Count']
mytable = PrettyTable()
mytable.add_column(columns[0], unique)
mytable.add_column(columns[1], tags.iloc[unique-1]['index'].values)
mytable.add_column(columns[2], counts)

print(mytable)
# Out:
# +-------------+---------------------+--------+
# | Predictions |         Tag         | Count  |
# +-------------+---------------------+--------+
# |      6      |   B-Collaboration   |  2858  |
# |      7      | B-ComputingFacility |   1    |
# |      25     |      B-Software     |   13   |
# |      30     |        B-URL        | 27982  |
# |      35     |  I-CelestialRegion  | 41241  |
# |      40     |      I-Dataset      |   1    |
# |      63     |          O          | 382299 |
# +-------------+---------------------+--------+

# %%
# having a look at the classification report of test tags
print(classification_report(convert_to_1D(test_tags),convert_to_1D(np.array(final_test))))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        40
#            2       0.00      0.00      0.00       404
#            3       0.00      0.00      0.00        35
#            4       0.00      0.00      0.00        23
#            5       0.00      0.00      0.00       627
#            6       0.00      0.03      0.00        36
#            7       0.00      0.00      0.00        54
#            8       0.00      0.00      0.00        41
#            9       0.00      0.00      0.00        18
#           10       0.00      0.00      0.00         1
#           11       0.00      0.00      0.00         4
#           12       0.00      0.00      0.00        53
#           13       0.00      0.00      0.00       402
#           14       0.00      0.00      0.00       303
#           15       0.00      0.00      0.00         4
#           16       0.00      0.00      0.00        89
#           17       0.00      0.00      0.00       248
#           18       0.00      0.00      0.00        11
#           19       0.00      0.00      0.00       194
#           20       0.00      0.00      0.00         8
#           21       0.00      0.00      0.00       158
#           22       0.00      0.00      0.00      1244
#           23       0.00      0.00      0.00       428
#           24       0.00      0.00      0.00         2
#           25       0.00      0.00      0.00       130
#           26       0.00      0.00      0.00        73
#           27       0.00      0.00      0.00         2
#           28       0.00      0.00      0.00       269
#           29       0.00      0.00      0.00         8
#           30       0.00      0.61      0.00        18
#           31       0.00      0.00      0.00       471
#           32       0.00      0.00      0.00       100
#           33       0.00      0.00      0.00       148
#           34       0.00      0.00      0.00        34
#           35       0.00      0.27      0.00        30
#           36       0.00      0.00      0.00      4125
#           37       0.00      0.00      0.00        81
#           38       0.00      0.00      0.00       147
#           39       0.00      0.00      0.00        37
#           40       0.00      0.00      0.00        31
#           42       0.00      0.00      0.00        18
#           43       0.00      0.00      0.00       175
#           44       0.00      0.00      0.00      1620
#           45       0.00      0.00      0.00       585
#           46       0.00      0.00      0.00         1
#           47       0.00      0.00      0.00        21
#           48       0.00      0.00      0.00        99
#           49       0.00      0.00      0.00         3
#           50       0.00      0.00      0.00       243
#           51       0.00      0.00      0.00         7
#           52       0.00      0.00      0.00       236
#           53       0.00      0.00      0.00      2603
#           54       0.00      0.00      0.00       144
#           55       0.00      0.00      0.00        21
#           56       0.00      0.00      0.00        75
#           57       0.00      0.00      0.00        82
#           58       0.00      0.00      0.00         5
#           59       0.00      0.00      0.00       127
#           60       0.00      0.00      0.00        10
#           61       0.00      0.00      0.00         4
#           62       0.00      0.00      0.00       249
#           63       0.96      0.99      0.97     94696
#
#     accuracy                           0.84    111155
#    macro avg       0.02      0.03      0.02    111155
# weighted avg       0.82      0.84      0.83    111155
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# having a look at the classification report of test data
print(classification_report(convert_to_1D(train_tags),convert_to_1D(np.array(final_train))))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       151
#            2       0.00      0.00      0.00      2370
#            3       0.00      0.00      0.00       228
#            4       0.00      0.00      0.00       129
#            5       0.00      0.00      0.00      4847
#            6       0.01      0.10      0.02       263
#            7       0.00      0.00      0.00       321
#            8       0.00      0.00      0.00       212
#            9       0.00      0.00      0.00       293
#           10       0.00      0.00      0.00        60
#           11       0.00      0.00      0.00        39
#           12       0.00      0.00      0.00       335
#           13       0.00      0.00      0.00      1667
#           14       0.00      0.00      0.00      2834
#           15       0.00      0.00      0.00       104
#           16       0.00      0.00      0.00       574
#           17       0.00      0.00      0.00      1118
#           18       0.00      0.00      0.00        92
#           19       0.00      0.00      0.00      1451
#           20       0.00      0.00      0.00       114
#           21       0.00      0.00      0.00       681
#           22       0.00      0.00      0.00      6073
#           23       0.00      0.00      0.00      3184
#           24       0.00      0.00      0.00        91
#           25       0.00      0.00      0.00       811
#           26       0.00      0.00      0.00       773
#           27       0.00      0.00      0.00        45
#           28       0.00      0.00      0.00      1242
#           29       0.00      0.00      0.00        43
#           30       0.01      0.65      0.01       243
#           31       0.00      0.00      0.00      2762
#           32       0.00      0.00      0.00       366
#           33       0.00      0.00      0.00      1373
#           34       0.00      0.00      0.00       185
#           35       0.00      0.55      0.01       202
#           36       0.00      0.00      0.00     14049
#           37       0.00      0.00      0.00       514
#           38       0.00      0.00      0.00       651
#           39       0.00      0.00      0.00       220
#           40       0.00      0.00      0.00       336
#           41       0.00      0.00      0.00        16
#           42       0.00      0.00      0.00       156
#           43       0.00      0.00      0.00       818
#           44       0.00      0.00      0.00      6653
#           45       0.00      0.00      0.00      3353
#           46       0.00      0.00      0.00        27
#           47       0.00      0.00      0.00       111
#           48       0.00      0.00      0.00       352
#           49       0.00      0.00      0.00        24
#           50       0.00      0.00      0.00       957
#           51       0.00      0.00      0.00        64
#           52       0.00      0.00      0.00       791
#           53       0.00      0.00      0.00     11494
#           54       0.00      0.00      0.00      1803
#           55       0.00      0.00      0.00        75
#           56       0.00      0.00      0.00       385
#           57       0.00      0.00      0.00       489
#           58       0.00      0.00      0.00        46
#           59       0.00      0.00      0.00       470
#           60       0.00      0.00      0.00        42
#           61       0.00      0.00      0.00         7
#           62       0.00      0.00      0.00      1319
#           63       0.97      0.99      0.98    373897
#
#     accuracy                           0.82    454395
#    macro avg       0.02      0.04      0.02    454395
# weighted avg       0.80      0.82      0.81    454395
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Printing the final train accuracy 
tru = 0
fal = 0
for i_s,j_s in zip(np.array(final_train),train_tags):
  for i,j in zip(i_s,j_s):
    if i==j:
      tru += 1
    else:
      fal +=1
train_accuracy = tru/(tru+fal)
print("The final training accuracy is : ", train_accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   after removing the cwd from sys.path.
# The final training accuracy is :  0.8166727186698798

# %%
tru = 0
fal = 0
for i_s,j_s in zip(np.array(final_test),test_tags):
  for i,j in zip(i_s,j_s):
    if i==j:
      tru += 1
    else:
      fal +=1
test_accuracy = tru/(tru+fal)
print("The final testing accuracy is : ", test_accuracy)
# Out:
# The final testing accuracy is :  0.8416265575097837
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   This is separate from the ipykernel package so we can avoid doing imports until
